# %% [markdown]
# # Initial configuration of my wifi6 router

# %% [markdown]
# ## General
#
# (remove WPA key)
#
# ![general settings](config_router/settings_20201214_init.png)
#
# ## Professional
# ![professional settings](config_router/settings_20201214_init_pro.png)

# %% [markdown]
# ## # of failure with this config

# %% [markdown]
# How to read this plot: I had a mean of 16 failures per hour on the 12th of December. (8 per unit)
#
# ![failures](plot/failure2020-12-14.png)

# %% [markdown]
# # wifi 6

# %% [markdown]
# ## 2020-12-15 at 10:40AM, disable wifi 6

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Just have to wait a couple of days to see if it has impact on the daily mean of failure.

# %% [markdown]
# (update 2020-12-17 9:45 AM) I don't see real impact. My guess is there is no link between wifi 6 and these failures.
#
# ![no impact when dsabling wifi 6](plot/failure2020-12-16_wifi6.png)

# %% [markdown]
# As a consequence I will reactivate wifi6 (at end of day to avoid network glitch)

# %% [markdown]
# ## 2020-12-17 at 2:00 PM, enable wifi 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # wireless scheduler
#
#
# I will stop wifi at night. Likely that if I don't see effects, that would be my router is not cause of these issues?

# %% [markdown]
# ## 2020-12-17 at 2:00 PM, enable wireless scheduler

# %% [markdown]
# ![wireless scheduler](config_router/20201217_wireless_scheduler_00-06AM.png)

# %% [markdown]
# This menu is in Professional, and these settings have to be done for 3 bands: 2.4 GHz, 5 GHz(1) and 5 GHz(2)
#
# ![professional](config_router/20201217_wireless_scheduler_00-06AM_Professional.png)

# %% [markdown]
# Have to wait 2-3 days to see effects.
