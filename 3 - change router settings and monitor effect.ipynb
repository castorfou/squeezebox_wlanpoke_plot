# %% [markdown]
# # Initial configuration of my wifi6 router

# %% [markdown]
# ## General
#
# (remove WPA key)
#
# ![general settings](config_router/settings_20201214_init.png)
#
# ## Professional
# ![professional settings](config_router/settings_20201214_init_pro.png)

# %% [markdown]
# ## # of failure with this config

# %% [markdown]
# How to read this plot: I had a mean of 16 failures per hour on the 12th of December. (8 per unit)
#
# ![failures](plot/failure2020-12-14.png)

# %% [markdown]
# # wifi 6

# %% [markdown]
# ## 2020-12-15 at 10:40AM, disable wifi 6

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Just have to wait a couple of days to see if it has impact on the daily mean of failure.

# %% [markdown]
# ## Conclusion: no effect of wifi 6

# %% [markdown]
# (update 2020-12-17 9:45 AM) I don't see real impact. My guess is there is no link between wifi 6 and these failures.
#
# ![no impact when dsabling wifi 6](plot/failure2020-12-16_wifi6.png)

# %% [markdown]
# As a consequence I will reactivate wifi6 (at end of day to avoid network glitch)

# %% [markdown]
# ## 2020-12-17 at 2:00 PM, enable wifi 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # wireless scheduler
#
#
# I will stop wifi at night. Likely that if I don't see effects, that would be my router is not cause of these issues?

# %% [markdown]
# ## 2020-12-17 at 2:00 PM, enable wireless scheduler

# %% [markdown]
# ![wireless scheduler](config_router/20201217_wireless_scheduler_00-06AM.png)

# %% [markdown]
# This menu is in Professional, and these settings have to be done for 3 bands: 2.4 GHz, 5 GHz(1) and 5 GHz(2)
#
# ![professional](config_router/20201217_wireless_scheduler_00-06AM_Professional.png)

# %% [markdown]
# Have to wait 2-3 days to see effects.

# %% [markdown]
# ## Conclusion: real effect of XT8 wifi

# %% [markdown]
# (2020-12-20) 2 days after, I can see a real effect. When wifi is off between 12AM and 6AM, #of failures is 0. (Actually is 0 from 12AM to 4AM) and is slowly increasing after and I can't explain why) (hypothesis: due to a reboot time setup daily at 5?)
#
#
# ![no wifi before 6AM](plot/2020-12-19.png)
#
# Overall effects so far:
# ![mean failures](plot/failure2020-12-19_wifi6_wifi.png)

# %% [markdown]
# ## 2020-12-20 at 11AM: disable wifi 5 GHz (1-2)

# %% [markdown]
# Re-enable wifi 2.4GHz
# ![image-2.png](attachment:image-2.png)
# But let 5 GHz-1, 5 GHz-2 off
#
#
# and disable daily reboot at 5AM
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion: real impact of wifi 2.4 GHz
#
# (2020-12-23 at 8AM) Real effect of wifi 2.4 GHz. When only this band is one, failures happen.
#
# ![](plot/2020-12-21.png)

# %% [markdown]
# ## 2020-12-23 at 8AM: disable of wifi 2.4 GHz

# %% [markdown]
# Disable wifi 2.4 GHz and re-enable wifi 5 GHz.

# %% [markdown]
# ## Conclusion: real effect of 2.4 GHz band

# %% [markdown]
# After one week of vacations, I am back.
#
# And when 2.4GHz is off between 0-6AM, then no diconnections happen.
#
# ![](plot/2020-12-31.png)
#
# So the next test is to disable completely 2.4GHz band. I will see if it is effective.

# %% [markdown]
# # Disable wifi 2.4 GHz

# %% [markdown]
# ## 2021-01-01 at 7 PM: disable permanently wifi 2.4 GHz

# %% [markdown]
# ![](config_router/no_wifi_2.4GHz.png)

# %% [markdown]
# ## Conclusion: real effect

# %% [markdown]
# ![](plot/2021-01-02.png)
#
# With this setting, # of failure has been divided by 2. Average of 2.5 failure per hour per device when I had an average of 5 with the standard settings.
#
# It is not yet perfect but maybe something to better understand.
#
# And I don't understand what happens between 11PM and 4 AM (no disconnections)
